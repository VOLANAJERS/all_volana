# %%
import requests
import json
import fire
import pandas as pd
import numpy as np
import pymysql

# %%
d = pd.read_csv("../data/comparativa_modelos.csv")

# %%
q = pd.read_csv("../../AnalisisProspectos/prospectos_riesgo_11_28_23.csv").id_distribuidor

# %%
np.intersect1d(q, d).shape
# Out:
# (1417,)

# %%
d
# Out:
#       Unnamed: 0  id_distribuidor  ID ASOCIADO  CAPITAL AUTORIZADO  \
# 0              0           145442       162807                6000
# 1              1           145444       162806                6000
# 2              2           157169       157637                8000
# 3              3           157171       157634               11000
# 4              4           157178       157635               11000
# ...          ...              ...          ...                 ...
# 1412        1412           167070       167255                9000
# 1413        1413           167202       167259                9000
# 1414        1414           166739       167256                9000
# 1415        1415           166784       167257                9000
# 1416        1416           166882       167258                9000
#
#       TASA AUTORIZADA    RECUPERADO  NO RECUPERADO CERRADO  P COSECHA  \
# 0                 142   6000.000000       0.000000      SI   0.000000
# ...
