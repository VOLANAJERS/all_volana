# %%
import pandas as pd

# %%
movo_27 = pd.read_csv("./Volana/Fideicomiso/JERS/data/2024-05-27/MOVO_2024-05-27.txt", sep = '|', 
            names= [
    "Contrato", "Anexo", "Número de documento", "Fecha Depósito", "Fecha Aplicación",
    "Monto de Principal", "Monto de interés", "Monto de IVA", "Tipo de Movimiento", "Cuenta", "paymentId"
])

movo_26 = pd.read_csv("./Volana/Fideicomiso/JERS/data/2024-05-26/MOVO_2024-05-26.txt", sep = '|', 
            names= [
    "Contrato", "Anexo", "Número de documento", "Fecha Depósito", "Fecha Aplicación",
    "Monto de Principal", "Monto de interés", "Monto de IVA", "Tipo de Movimiento", "Cuenta", "paymentId"
])

movo_23 = pd.read_csv("./Volana/Fideicomiso/JERS/data/2024-05-23/MOVO_2024-05-23.txt", sep = '|', 
            names= [
    "Contrato", "Anexo", "Número de documento", "Fecha Depósito", "Fecha Aplicación",
    "Monto de Principal", "Monto de interés", "Monto de IVA", "Tipo de Movimiento", "Cuenta", "paymentId"
])

movo_21 = pd.read_csv("./Volana/Fideicomiso/JERS/data/2024-05-21/MOVO_2024-05-21.txt", sep = '|', 
            names= [
    "Contrato", "Anexo", "Número de documento", "Fecha Depósito", "Fecha Aplicación",
    "Monto de Principal", "Monto de interés", "Monto de IVA", "Tipo de Movimiento", "Cuenta", "paymentId"
])

movo_20 = pd.read_csv("./Volana/Fideicomiso/JERS/data/2024-05-20/MOVO_2024-05-20.txt", sep = '|', 
            names= [
    "Contrato", "Anexo", "Número de documento", "Fecha Depósito", "Fecha Aplicación",
    "Monto de Principal", "Monto de interés", "Monto de IVA", "Tipo de Movimiento", "Cuenta", "paymentId"
])

# %%
movo_27.query("Contrato == 185930").sort_values(by = 'Fecha Aplicación', ascending=False)
# Out:
#        Contrato Anexo  Número de documento Fecha Depósito Fecha Aplicación  \
# 44411    185930     N               114612     2024-05-24       2024-05-25
# 44277    185930     N               114612     2024-05-18       2024-05-20
# 44217    185930     N               114612     2024-05-17       2024-05-18
# 44246    185930     N               114612     2024-05-17       2024-05-17
# 43956    185930     N               114612     2024-05-10       2024-05-13
# 44016    185930     N               114612     2024-05-11       2024-05-13
# 43662    185930     N               114612     2024-05-03       2024-05-04
# 43667    185930     N               114612     2024-05-03       2024-05-04
# 43461    185930     N               114612     2024-04-29       2024-04-29
#
#        Monto de Principal  Monto de interés  Monto de IVA Tipo de Movimiento  \
# 44411             -227.62           -839.12       -134.26                PAG
# ...

# %%
movo_26.query("Contrato == 185930").sort_values(by = 'Fecha Aplicación', ascending=False)
# Out:
#        Contrato Anexo  Número de documento Fecha Depósito Fecha Aplicación  \
# 44210    185930     N               114670     2024-05-17       2024-05-18
# 44244    185930     N               114670     2024-05-17       2024-05-17
# 43940    185930     N               114670     2024-05-10       2024-05-13
# 44016    185930     N               114670     2024-05-11       2024-05-13
# 43666    185930     N               114670     2024-05-03       2024-05-04
# 43671    185930     N               114670     2024-05-03       2024-05-04
# 43449    185930     N               114670     2024-04-29       2024-04-29
#
#        Monto de Principal  Monto de interés  Monto de IVA Tipo de Movimiento  \
# 44210            -2093.25           -948.92       -151.83                PAG
# 44244            -1201.00              0.00          0.00                PAG
# 43940              -29.87          -1009.59       -161.54                PAG
# ...

# %%
movo_23.query("Contrato == 185930").sort_values(by = 'Fecha Aplicación', ascending=False)
# Out:
#        Contrato Anexo  Número de documento Fecha Depósito Fecha Aplicación  \
# 44211    185930     N               114670     2024-05-17       2024-05-18
# 44228    185930     N               114670     2024-05-17       2024-05-17
# 43962    185930     N               114670     2024-05-10       2024-05-13
# 44030    185930     N               114670     2024-05-11       2024-05-13
# 43679    185930     N               114670     2024-05-03       2024-05-04
# 43684    185930     N               114670     2024-05-03       2024-05-04
# 43471    185930     N               114670     2024-04-29       2024-04-29
#
#        Monto de Principal  Monto de interés  Monto de IVA Tipo de Movimiento  \
# 44211            -2093.25           -948.92       -151.83                PAG
# 44228            -1201.00              0.00          0.00                PAG
# 43962              -29.87          -1009.59       -161.54                PAG
# ...
